# %%
import numpy as np
from PIL import Image
from ultralytics import YOLO
import cv2
from ultralytics.utils.plotting import Annotator, colors

# %% [markdown]
# Hense - only about the cars visable from the current camera angle.
#
# The maximum number of parking spots in the 'Upper Level': 20
# The maximum number of parking spots in the 'Close Perp Line': 8
# The maximum number of parking spots in the 'Small Parking': 9
# The maximum number of parking spots in the 'Far Side': 4
# The maximum number of parking spots in the 'Close Side': 3
# The maximum number of parking spots in the 'Far Perp Line': 4
#
# ![image.png](attachment:image.png)

# %%
model = YOLO('yolov8n.pt')

# %%
results = model(['Assets/1.jpg','Assets/2.jpg','Assets/3.jpg','Assets/4.jpg','Assets/5.jpg','Assets6.jpg','Assets/7.jpg','Assets/8.jpg','Assets/9.jpg'])

# %%
results = model(source='Assets/1.jpg',show=False, conf=0.05,save=True,classes=2)
